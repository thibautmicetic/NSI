# %%
def possibilite_suivante(possibilite, liste_des_max):
    lng = len(possibilite)
    i = 0
    while i < lng and possibilite[i] < liste_des_max[i]:
        possibilite[i] = 0
        i += 1
    if i < lng:
        possibilte[i] += 1
        return True
    else:
        return False
        
        
def enumerer_systeme(a_rendre, systeme):
    l_sys = len(systeme)
    liste_des_max = [a_rendre // piece for piece in systeme]
    soluce = liste_des_max
    possibilite = [0] * l_sys
    
    fini = False
    
    while not fini:
        print('->', possibilite)
        if sum(nb * piece for nb, piece in zip(possibilite, systeme)) == a_rendre:
            if sum(possibilite) < sum(soluce):
                soluce = possibilite.copy()            
                
        fini = not(possibilite_suivante(possibilite, liste_des_max))
    return soluce
