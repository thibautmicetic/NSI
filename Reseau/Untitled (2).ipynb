# %%
import threading
import requests

class File:
    
    def __init__(self):
        _mafile = []
        
    def __len__(self):
        return len(self._mafile)
    
    def est_vide(self):
        return len(self) == 0
    
    def enfiler(self, element):
        self._mafile.append(element)
        
    def defiler(self):
        self._mafile.pop(0)
        

def get_url(f, url):
    f.enfiler((url, request.get(url)))
    
urls = ["https://www.ac-nantes.fr", "http://cobac.free.fr",
       "https://docs.python.org/fr/3/library/threading.html",
       "https://duckduckgo.fr"]

f = File()

for url in urls:
    t = threading.Thread(target=get_url)
