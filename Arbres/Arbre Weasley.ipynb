# %%
descendance_molly = {
    "molly": {
        "ginny": {
            "James" : {},
            "Albus" : {},
            "Lily" : {}
        },
        "George" : {
            "Roxanne" : {},
            "Fred" : {}
        },
        "Ron" : {
            "Rose" : {},
            "Hugo" : {}
        },
        "Bill" : {
            "Victorie" : {},
            "Dominique" : {},
            "Louis" : {}
        }
        
    }
}

# %%
def parcours(dico):
    if not dico: return
    for cle in dico:
        print("\t" * profondeur + 1)
        parcours(dico[cle], profondeur + 1)

# %%
def hauteur(dico):
    if not dico: return 0
    liste_hauteurs = [hauteur(dico[cle]) for cle in dico]
    return 1 + max(liste_hauteurs)

hauteur(descendance_molly)

# %%
descendance_molly = {
    "molly": ["ginny", "George", "Fred", "Ron", "Percy", "Bill", "Charlie"],
    "Ginny" : ["James", "Albus", "Lily"],
    "Ron" :  ["Rose", "Hugo"],
    "George" : ["Roxanne", "Fred2"],
    "Bill" : ["Victorie", "Dominique", "Louis"],
    "Percy" : ["Lucy", "Mollie2"]
}

# %%
def parcours(dico, cle_de_depart):
    for personnage in dico[cle_de_depart]:
        print(personnage)
        if personnage in dico:
            parcours(dico, personnage)

parcours(descendance_molly, "molly")

# %%
def hauteur(dico, cle_de_depart):
    if cle_de_depart not in dico: return 1 
    liste_hauteurs = [hauteur(dico, personnage) for ]

hauteur(descendance_molly, "molly")
