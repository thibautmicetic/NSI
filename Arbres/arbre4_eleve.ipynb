# %%
class Noeud:
    def __init__(self, etiquette, gauche=None, droit=None):
        self.etiquette = etiquette
        self.gauche = gauche
        self.droit = droit
        
    def __len__(self):
        lg = 0 if self.gauche is None else len(self.gauche)
        ld = 0 if self.droit is None else len(self.droit)
        return 1 + lg + ld 
    
    def est_une_feuille(self):
        return not (self.gauce or self.droit)
    
    def hauteur(self):
        if self.est_une_feuille():
            return 1
        else:
            hg = 0 if self.gauche is None else self.gauche.hauteur()
            hd = 0 if self.droit is None else self.droit.hauteur()
            return 1 + max(hg, hd)
        
    def p_largeur(self):
        f = File()
        f.enfiler(self)
        liste = []
        while not f.est_vide():
            pass
            # à compléter
        return liste
